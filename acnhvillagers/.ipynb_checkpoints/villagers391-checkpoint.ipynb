# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
polls = pd.read_csv("villagers_polls.csv",index_col=0)

# %%
polls.head()
# Out:
#          Jun-20  Jul-20  Aug-20  Sep-20  Oct-20  Nov-20  Dec-20  Jan-21  \
# Name
# Admiral      84     104      66      29      29      24      34      22
# Agent S     226     235      96      65      65      41      36      44
# Agnes       376     400     228     146     146      95      85      96
# Al          110     123      46      31      31      20      15      15
# Alfonso     241     214     108      53      53      29      26      40
#
#          Feb-21  Mar-21  Apr-21  May-21  Jun-21  Jul-21  Aug-21  Sep-21  \
# Name
# Admiral      29      37      25      23      16       9      10       7
# Agent S      36      50      36      27      13      21      16      14
# Agnes       116     120      92      70      49      45      38      29
# Al           20      23      18       6      15      10      12       7
# Alfonso      55      80      50      45      28      12      13       9
#
#          Oct-21
# Name
# Admiral      11
# Agent S      22
# Agnes        64
# Al           15
# Alfonso      25

# %%
traits0 = pd.read_csv("villagers_traits.csv",index_col=0)

# %%
traits0.head()
# Out:
#            Species  Gender Personality    Hobby Birthday Catchphrase  \
# Name
# Admiral       Bird    Male      Cranky   Nature   27-Jan     aye aye
# Agent S   Squirrel  Female       Peppy  Fitness    2-Jul    sidekick
# Agnes          Pig  Female  Big Sister     Play   21-Apr     snuffle
# Al         Gorilla    Male        Lazy  Fitness   18-Oct     ayyyeee
# Alfonso  Alligator    Male        Lazy     Play    9-Jun    it'sa me
#
#          Favorite Song Style 1  Style 2 Color 1 Color 2  \
# Name
# Admiral     Steep Hill    Cool     Cool   Black    Blue
# Agent S  Go K.K. Rider  Active   Simple    Blue   Black
# Agnes       K.K. House  Simple  Elegant    Pink   White
# Al       Go K.K. Rider  Active   Active     Red   White
# Alfonso    Forest Life  Simple   Simple     Red    Blue
#
#                       Wallpaper                Flooring  \
# Name
# Admiral          dirt-clod wall                  tatami
# Agent S           concrete wall  colorful tile flooring
# Agnes    gray molded-panel wall      arabesque flooring
# Al                concrete wall   green rubber flooring
# Alfonso    yellow playroom wall    green honeycomb tile
#
#                                             Furniture List Filename  \
# Name
# Admiral  717;1849;7047;2736;787;5970;3449;3622;3802;410...    brd06
# Agent S  7845;7150;3468;4080;290;3971;3449;1708;4756;25...    squ05
# Agnes    4129;7236;7235;7802;896;3428;4027;7325;3958;71...    pig17
# Al       1452;4078;4013;833;4116;3697;7845;3307;3946;39...    gor08
# Alfonso  4763;3205;3701;1557;3623;85;3208;3584;4761;121...    crd00
#
#            Unique Entry ID
# Name
# Admiral  B3RyfNEqwGmcccRC3
# Agent S  SGMdki6dzpDZyXAw5
# Agnes    jzWCiDPm9MqtCfecP
# Al       LBifxETQJGEaLhBjC
# Alfonso  REpd8KxB8p9aGBRSE

# %%
#total poll numbers for each villager

pollsum=polls.sum(axis='columns')
pollsum.rename("PollSum")
# Out:
# Name
# Admiral       559
# Agent S      1043
# Agnes        2195
# Al            517
# Alfonso      1081
#             ...
# Winnie        338
# Wolfgang     2357
# Yuka          416
# Zell         2493
# Zucker      15247
# Name: PollSum, Length: 391, dtype: int64

# %%
pollsum.head(10)
# Out:
# Name
# Admiral      559
# Agent S     1043
# Agnes       2195
# Al           517
# Alfonso     1081
# Alice       1162
# Alli         205
# Amelia       606
# Anabelle     872
# Anchovy      594
# dtype: int64

# %%
pollsum.sort_values(ascending=False).head(12)
# Out:
# Name
# Marshal     25481
# Raymond     23901
# Sherb       16983
# Zucker      15247
# Judy        12687
# Marina      11537
# Stitches    10674
# Ankha       10584
# Audie       10485
# Fauna       10042
# Beau         9775
# Dom          9661
# dtype: int64

# %%
top10=pollsum.sort_values(ascending=False).head(10)
top10
# Out:
# Name
# Marshal     25481
# Raymond     23901
# Sherb       16983
# Zucker      15247
# Judy        12687
# Marina      11537
# Stitches    10674
# Ankha       10584
# Audie       10485
# Fauna       10042
# dtype: int64

# %%
plt.figure(figsize=(10,4))

plt.bar(x=top10.index,height=top10)

plt.title("Total Votes From June 2020 to Oct 2021, Top 10 Villagers")

plt.show()

# %%
type(top10)
# Out:
# pandas.core.series.Series

# %%
top10.index
# Out:
# Index(['Marshal', 'Raymond', 'Sherb', 'Zucker', 'Judy', 'Marina', 'Stitches',
#        'Ankha', 'Audie', 'Fauna'],
#       dtype='object', name='Name')

# %%
bot10=pollsum.sort_values().head(10)
bot10
# Out:
# Name
# Violet      134
# Snooty      137
# Bitty       139
# Limberg     141
# Harry       145
# Pancetti    147
# Rizzo       147
# Boyd        149
# Moose       150
# Greta       154
# dtype: int64

# %%
plt.figure(figsize=(10,4))

plt.bar(x=bot10.index,height=bot10)

plt.title("Total Votes From June 2020 to Oct 2021, Bottom 10 Villagers")

plt.show()

# %%
series5=pollsum.loc[['Sherb','Megan','Dom','Audie','Cyd','Judy','Raymond','Reneigh']].sort_values(ascending=False)

series5
# Out:
# Name
# Raymond    23901
# Sherb      16983
# Judy       12687
# Audie      10485
# Dom         9661
# Reneigh     1842
# Megan        946
# Cyd          719
# dtype: int64

# %%
plt.figure(figsize=(10,4))

plt.bar(x=series5.index,height=series5)

plt.title("Total Votes From June 2020 to Oct 2021, Villagers in Series 5")

plt.show()

# %%
#combine dataframe with pollsum and villager traits.

traits=traits0.loc[:,['Species','Personality','Gender','Style 1','Color 1','Hobby']]

traits
# Out:
#             Species Personality  Gender Style 1 Color 1      Hobby
# Name
# Admiral        Bird      Cranky    Male    Cool   Black     Nature
# Agent S    Squirrel       Peppy  Female  Active    Blue    Fitness
# Agnes           Pig  Big Sister  Female  Simple    Pink       Play
# Al          Gorilla        Lazy    Male  Active     Red    Fitness
# Alfonso   Alligator        Lazy    Male  Simple     Red       Play
# ...             ...         ...     ...     ...     ...        ...
# Winnie        Horse       Peppy  Female    Cool   White    Fashion
# Wolfgang       Wolf      Cranky    Male    Cool   Black  Education
# Yuka          Koala      Snooty  Female    Cool  Orange    Fashion
# Zell           Deer        Smug    Male    Cool  Purple      Music
# Zucker      Octopus        Lazy    Male  Simple    Blue     Nature
#
# [391 rows x 6 columns]

# %%
polltrait=pd.concat([traits,pollsum],axis=1)
polltrait.rename(columns={0:'PollSum'},inplace=True)
polltrait
# Out:
#             Species Personality  Gender Style 1 Color 1      Hobby  PollSum
# Name
# Admiral        Bird      Cranky    Male    Cool   Black     Nature      559
# Agent S    Squirrel       Peppy  Female  Active    Blue    Fitness     1043
# Agnes           Pig  Big Sister  Female  Simple    Pink       Play     2195
# Al          Gorilla        Lazy    Male  Active     Red    Fitness      517
# Alfonso   Alligator        Lazy    Male  Simple     Red       Play     1081
# ...             ...         ...     ...     ...     ...        ...      ...
# Winnie        Horse       Peppy  Female    Cool   White    Fashion      338
# Wolfgang       Wolf      Cranky    Male    Cool   Black  Education     2357
# Yuka          Koala      Snooty  Female    Cool  Orange    Fashion      416
# Zell           Deer        Smug    Male    Cool  Purple      Music     2493
# Zucker      Octopus        Lazy    Male  Simple    Blue     Nature    15247
#
# [391 rows x 7 columns]

# %%
polltrait.groupby('Personality').PollSum.mean().sort_values(ascending=False)
# Out:
# Personality
# Smug          2353.764706
# Normal        2173.220339
# Lazy          2068.650000
# Peppy         1715.428571
# Big Sister    1239.833333
# Snooty        1009.109091
# Jock           996.272727
# Cranky         739.909091
# Name: PollSum, dtype: float64

# %%
polltrait.groupby('Personality').PollSum.std().sort_values(ascending=False)
#smug must be huge because of the biggest and smallest numbers
# Out:
# Personality
# Smug          5775.738626
# Lazy          3597.519413
# Normal        2781.536322
# Snooty        2336.664738
# Peppy         2188.223880
# Jock          1731.178056
# Big Sister    1084.930119
# Cranky         989.541856
# Name: PollSum, dtype: float64

# %%
polltrait.groupby('Personality').PollSum.median().sort_values(ascending=False)
# Out:
# Personality
# Normal        944.0
# Big Sister    905.5
# Peppy         872.0
# Lazy          654.5
# Smug          567.5
# Jock          454.0
# Cranky        398.0
# Snooty        285.0
# Name: PollSum, dtype: float64

# %%
polltrait.groupby('Personality').PollSum.min().sort_values(ascending=False)
# Out:
# Personality
# Big Sister    179
# Normal        176
# Smug          172
# Peppy         170
# Lazy          168
# Jock          150
# Cranky        141
# Snooty        134
# Name: PollSum, dtype: int64

# %%
plt.figure(figsize=(10,4))

sns.barplot(data=polltrait,x='Personality',y='PollSum',
            order=polltrait.groupby('Personality').PollSum.mean().sort_values(ascending=False).index)

plt.show()

# %%
plt.figure(figsize=(12,4))

sns.barplot(data=polltrait,x='Species',y='PollSum',
           order=polltrait.groupby('Species').PollSum.mean().sort_values(ascending=False).index)

plt.xticks(rotation=60)

plt.show()

# %%
plt.figure(figsize=(5,4))

sns.barplot(data=polltrait,x='Gender',y='PollSum')

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.barplot(data=polltrait,x='Style 1',y='PollSum',
            order=polltrait.groupby('Style 1').PollSum.mean().sort_values(ascending=False).index)

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.barplot(data=polltrait,x='Color 1',y='PollSum',
            order=polltrait.groupby('Color 1').PollSum.mean().sort_values(ascending=False).index)

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.barplot(data=polltrait,x='Hobby',y='PollSum',
            order=polltrait.groupby('Hobby').PollSum.mean().sort_values(ascending=False).index)

plt.show()

# %%
polltrait.loc[polltrait.Species=="Octopus"].sort_values(by="PollSum")
# Out:
#           Species Personality  Gender Style 1 Color 1   Hobby  PollSum
# Name
# Octavian  Octopus      Cranky    Male    Cool   Black    Play     3952
# Marina    Octopus      Normal  Female    Cute    Pink   Music    11537
# Zucker    Octopus        Lazy    Male  Simple    Blue  Nature    15247

# %%
polltrait.loc[polltrait.Species=="Deer"].sort_values(by="PollSum")
# Out:
#         Species Personality  Gender   Style 1 Color 1      Hobby  PollSum
# Name
# Bruce      Deer      Cranky    Male      Cool   Black     Nature      893
# Lopez      Deer        Smug    Male  Gorgeous    Gray  Education     1151
# Deirdre    Deer  Big Sister  Female    Simple  Orange       Play     1401
# Fuchsia    Deer  Big Sister  Female      Cool    Pink      Music     1483
# Bam        Deer        Jock    Male    Active   Green       Play     2295
# Zell       Deer        Smug    Male      Cool  Purple      Music     2493
# Diana      Deer      Snooty  Female   Elegant  Purple  Education     7012
# Erik       Deer        Lazy    Male    Simple   Beige     Nature     8355
# Beau       Deer        Lazy    Male    Simple   Beige     Nature     9775
# Fauna      Deer      Normal  Female    Simple   Beige     Nature    10042

# %%
polltrait.loc[polltrait.Species=="Cat"].sort_values(by="PollSum")
# Out:
#          Species Personality  Gender   Style 1   Color 1      Hobby  PollSum
# Name
# Kitty        Cat      Snooty  Female   Elegant     Green    Fashion      285
# Monique      Cat      Snooty  Female  Gorgeous    Purple    Fashion      286
# Tom          Cat      Cranky    Male      Cool     Black  Education      539
# Stinky       Cat        Jock    Male    Active       Red    Fitness      549
# Moe          Cat        Lazy    Male    Active     Black       Play      644
# Purrl        Cat      Snooty  Female      Cool      Gray    Fashion      716
# Tabby        Cat       Peppy  Female    Active     Black      Music      912
# Felicity     Cat       Peppy  Female      Cute    Yellow    Fashion     1012
# Olivia       Cat      Snooty  Female      Cool     White      Music     1178
# Rudy         Cat        Jock    Male    Active    Yellow       Play     1306
# Mitzi        Cat      Normal  Female    Simple     Brown  Education     1394
# Katt         Cat  Big Sister  Female      Cool    Purple      Music     1873
# Kid Cat      Cat        Jock    Male    Active       Red    Fitness     2234
# Kabuki       Cat      Cranky    Male    Simple    Purple      Music     2528
# Kiki         Cat      Normal  Female    Simple     Brown  Education     3166
# Punchy       Cat        Lazy    Male    Simple      Blue       Play     3323
# Rosie        Cat       Peppy  Female      Cute      Pink      Music     4436
# Tangy        Cat       Peppy  Female    Simple     Green      Music     4744
# Lolly        Cat      Normal  Female    Simple      Gray      Music     7786
# Bob          Cat        Lazy    Male    Simple  Colorful       Play     8832
# Merry        Cat       Peppy  Female      Cute      Pink    Fashion     8954
# Ankha        Cat      Snooty  Female  Gorgeous  Colorful     Nature    10584
# Raymond      Cat        Smug    Male   Elegant     Black     Nature    23901

# %%
polltrait.loc[polltrait.Personality=="Smug"].sort_values(by="PollSum")
# Out:
#            Species Personality Gender   Style 1     Color 1      Hobby  \
# Name
# Chops          Pig        Smug   Male  Gorgeous         Red  Education
# Lucha         Bird        Smug   Male    Active       Black    Fitness
# Ed           Horse        Smug   Male  Gorgeous       Black     Nature
# Huck          Frog        Smug   Male    Simple       Green    Fitness
# Hippeux      Hippo        Smug   Male   Elegant       Brown  Education
# Leopold       Lion        Smug   Male   Elegant      Purple  Education
# Curlos       Sheep        Smug   Male    Active         Red     Nature
# Hans       Gorilla        Smug   Male   Elegant        Gray    Fitness
# Olaf      Anteater        Smug   Male   Elegant         Red  Education
# Quillson      Duck        Smug   Male   Elegant       Beige      Music
# Keaton       Eagle        Smug   Male  Gorgeous        Blue      Music
# Lionel        Lion        Smug   Male  Gorgeous       Green      Music
# Klaus         Bear        Smug   Male    Simple        Gray  Education
# Ken        Chicken        Smug   Male      Cool      Purple  Education
# Graham     Hamster        Smug   Male    Simple       Green  Education
# Tex        Penguin        Smug   Male      Cool       Black      Music
# Jacques       Bird        Smug   Male      Cool       Green      Music
# Colton       Horse        Smug   Male  Gorgeous        Blue     Nature
# Phil       Ostrich        Smug   Male   Elegant       Green      Music
# Beardo        Bear        Smug   Male   Elegant       Brown  Education
# Chadder      Mouse        Smug   Male   Elegant       Black    Fitness
# Rodney     Hamster        Smug   Male  Gorgeous        Pink      Music
# O'Hare      Rabbit        Smug   Male    Active        Blue     Nature
# Eugene       Koala        Smug   Male      Cool       Black      Music
# Kidd          Goat        Smug   Male   Elegant        Gray  Education
# Lopez         Deer        Smug   Male  Gorgeous        Gray  Education
# Henry         Frog        Smug   Male      Cool  Light blue      Music
# Shep           Dog        Smug   Male    Simple  Light blue  Education
# Kyle          Wolf        Smug   Male  Gorgeous       Black      Music
# Zell          Deer        Smug   Male      Cool      Purple      Music
# Pietro       Sheep        Smug   Male  Gorgeous    Colorful      Music
# Julian       Horse        Smug   Male  Gorgeous      Purple      Music
# Raymond        Cat        Smug   Male   Elegant       Black     Nature
# Marshal   Squirrel        Smug   Male   Elegant  Light blue      Music
#
#           PollSum
# Name
# Chops         172
# Lucha         264
# Ed            278
# Huck          280
# Hippeux       318
# Leopold       345
# Curlos        350
# Hans          361
# Olaf          370
# Quillson      388
# Keaton        389
# Lionel        411
# Klaus         471
# Ken           500
# Graham        504
# Tex           514
# Jacques       563
# Colton        572
# Phil          613
# Beardo        646
# Chadder       684
# Rodney        706
# O'Hare        718
# Eugene       1106
# Kidd         1148
# Lopez        1151
# Henry        1332
# Shep         1537
# Kyle         1920
# Zell         2493
# Pietro       4714
# Julian       4828
# Raymond     23901
# Marshal     25481
